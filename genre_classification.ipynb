# %% [markdown]
# <a href="https://colab.research.google.com/github/tamil038/codsoft/blob/main/genre_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
train_path = "/content/train_data.csv"
train_data = pd.read_csv(train_path, sep = ':::', names = ['Title', 'Genre', 'Description'], engine = 'python')

# %%
train_data.head(10)
# Out:
#                                   Title          Genre  \
# 1         Oscar et la dame rose (2009)          drama
# 2                         Cupid (1997)       thriller
# 3     Young, Wild and Wonderful (1980)          adult
# 4                The Secret Sin (1915)          drama
# 5               The Unrecovered (2007)          drama
# 6               Quality Control (2011)    documentary
# "7                ""Pink Slip"" (2009)         comedy
# 8                 One Step Away (1985)          crime
# "9          ""Desperate Hours"" (2016)     reality-tv
# 10                    Spirits (2014/I)         horror
#
#                                            Description
# 1     Listening in to a conversation between his do...
# 2     A brother and sister with a past incestuous r...
# 3     As the bus empties the students for their fie...
# 4     To help their unemployed father make ends mee...
# 5     The film's title refers not only to the un-re...
# ...

# %%
train_data.tail(10)
# Out:
#                                          Title          Genre  \
# 4753                     Suburban Zero (2011)        mystery
# 4754                           Napalsu (1979)          drama
# 4755                     Buffalo Flats (????)          drama
# 4756            The Da Vinci Detective (2006)    documentary
# 4757   The Sisters of Mercy Manchester (2008)          short
# 4758                Angshumaner Chhobi (2009)          drama
# 4759                 Kamerayla Izdivac (2010)    documentary
# 4760              Lost: 2010 PaleyFest (2010)      talk-show
# 4761           Oy Vey! My Son Is Gay!! (2009)         comedy
# 4762      Sergio Leone: Cinema, Cinema (2001)    documentary
#
#                                             Description
# 4753   The suburbs are a labyrinth. A man is stuck. ...
# 4754   As a child, Hae-su lacked a father's affectio...
# 4755    Details of the plot are being kept under wraps.
# 4756   This is no ordinary art history programme, bu...
# ...

# %%
train_data.shape
# Out:
# (4762, 3)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4762 entries, 1 to 4762
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Title        4762 non-null   object
#  1   Genre        4762 non-null   object
#  2   Description  4762 non-null   object
# dtypes: object(3)
# memory usage: 148.8+ KB

# %%
train_data.describe()
# Out:
#                                  Title    Genre  \
# count                             4762     4762
# unique                            4762       27
# top      Oscar et la dame rose (2009)    drama
# freq                                 1     1188
#
#                                               Description
# count                                                4762
# unique                                               4760
# top      Held since 2005, Film Spring Open-Air has bee...
# freq                                                    2

# %%
train_data.isna().sum()
# Out:
# Title          0
# Genre          0
# Description    0
# dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.datasets import fetch_20newsgroups

# Assuming 'text' and 'genre' are the column names in your DataFrame
text_column = 'Title'  # Replace 'Title' with the actual column name containing the text data
genre_column = 'Genre'  # Replace 'Genre' with the actual column name containing the labels

# Load dataset
X_train, X_test, y_train, y_test = train_test_split(train_data[text_column], train_data[genre_column], test_size=0.2, random_state=42)

# Build pipeline with TF-IDF and Logistic Regression
model = make_pipeline(TfidfVectorizer(), LogisticRegression(max_iter=1000))
model.fit(X_train, y_train)

# Function to predict the genre
def predict_genre(plot_summary):
    prediction = model.predict([plot_summary])
    # Get the index of the predicted class
    # Convert prediction to numerical index if it's not already
    predicted_index = prediction[0]
    if isinstance(predicted_index, str):
        unique_genres = train_data[genre_column].unique()
        predicted_index = np.where(unique_genres == predicted_index)[0][0]  # Find index of predicted genre

    # Get the list of unique genres
    unique_genres = train_data[genre_column].unique()
    # Check if the predicted index is within the bounds of the unique genres array
    if 0 <= predicted_index < len(unique_genres):
        return unique_genres[predicted_index]  # Use unique values from the genre column
    else:
        return "Unknown Genre" # Handle the case where the prediction is out of bounds

# Get user input and predict genre
user_input = input("Enter a movie plot summary: ")
print("Predicted Genre:", predict_genre(user_input))
# Out:
# Enter a movie plot summary: A filmmaker investigates the environmental impact of plastic waste on ocean life, uncovering the devastating effects on marine ecosystems and calling for urgent global action to reduce plastic pollution.
# Predicted Genre:  documentary
